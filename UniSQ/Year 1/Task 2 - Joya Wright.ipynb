# %%
numbers=input("Enter '1,2,3'")
def number_grid(a,b,c):#creating the grid star
    if numbers=="1,2,3" or "123" or "1 2 3":
        result =''
        for row in range(6): #setting up the numbers of rows
            for column in range(17):# setting up the number of columns
                if (column>1 and column>17 and row>=1 and row<=5)or(column>7 and column<11 and row>=1 and row<=5)or(column>13 and column<17 and row>0):
                    result+='*'
                else:
                    result+='\n'
            print(result)

number_grid(1,2,3)
# Out:
# Enter '1,2,3'123
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
# ***
#
#
# ***
#
#
#
#
#
#
#
# ***
#
#
# ***
